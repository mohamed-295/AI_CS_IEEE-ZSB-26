# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# # EDA

# %%
df = pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv')
df.head(5)
# Out:
#    Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0  Female   21    1.62    64.0                            yes   no   2.0  3.0
# 1  Female   21    1.52    56.0                            yes   no   3.0  3.0
# 2    Male   23    1.80    77.0                            yes   no   2.0  3.0
# 3    Male   27    1.80    87.0                             no   no   3.0  3.0
# 4    Male   22    1.78    89.8                             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#             NObeyesdad
# ...

# %%
print(df.shape)
# Out:
# (2111, 17)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   str
#  1   Age                             2111 non-null   int64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   str
#  5   FAVC                            2111 non-null   str
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   str
#  9   SMOKE                           2111 non-null   str
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   str
# ...

# %%
print(df.isnull().sum())
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %% [markdown]
# Now we can see that the data checks for overwight as `NObeyesdad` is the target let's visualize it for more understanding

# %%
plt.figure(figsize=(9,6))
df['NObeyesdad'].value_counts().plot(kind='bar')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Preprocessing

# %%
# Separete the features and target 

X = df.drop('NObeyesdad',axis=1)
y =  df['NObeyesdad']

# Encode the target 
label_enc = LabelEncoder()
y_enc = label_enc.fit_transform(y)

# Encode categorial features with one hot encoder
X_enc = pd.get_dummies(X,drop_first=True)
print(X_enc.shape)
X_enc.head()
# Out:
# (2111, 23)
#    Age  Height  Weight  FCVC  NCP  CH2O  FAF  TUE  Gender_Male  \
# 0   21    1.62    64.0   2.0  3.0   2.0  0.0  1.0        False
# 1   21    1.52    56.0   3.0  3.0   3.0  3.0  0.0        False
# 2   23    1.80    77.0   2.0  3.0   2.0  2.0  1.0         True
# 3   27    1.80    87.0   3.0  3.0   2.0  2.0  0.0         True
# 4   22    1.78    89.8   2.0  1.0   2.0  0.0  0.0         True
#
#    family_history_with_overweight_yes  ...  CAEC_no  SMOKE_yes  SCC_yes  \
# 0                                True  ...    False      False    False
# 1                                True  ...    False       True     True
# 2                                True  ...    False      False    False
# 3                               False  ...    False      False    False
# 4                               False  ...    False      False    False
#
#    CALC_Frequently  CALC_Sometimes  CALC_no  MTRANS_Bike  MTRANS_Motorbike  \
# ...

# %% [markdown]
# # Split & Scale

# %%
scaler = StandardScaler()
X_train_sc= scaler.fit_transform(X_enc)

X_train, X_test, y_train, y_test = train_test_split(X_train_sc, y_enc, test_size=0.2, random_state=42)

print("Training shape:", X_train.shape)
print("Testing shape:", X_test.shape)
# Out:
# Training shape: (1688, 23)
# Testing shape: (423, 23)

# %% [markdown]
# # Training the model

# %%
log_model = LogisticRegression(random_state=42)
log_model.fit(X_train,y_train)

y_pred_log = log_model.predict(X_test)

#Evaluation 
test_accuracy = accuracy_score(y_test, y_pred_log)
print('The test accuracy is', test_accuracy)

#Confusion MATRIX
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred_log), annot=True, fmt='d', cmap='Blues', xticklabels=label_enc.classes_, yticklabels=label_enc.classes_)
plt.title('Logistic Regression')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# The test accuracy is 0.8676122931442081

# %%
tree_model = DecisionTreeClassifier(random_state=42)
tree_model.fit(X_train,y_train)

y_pred_tree = tree_model.predict(X_test)

#Evaluation 
test_accuracy = accuracy_score(y_test, y_pred_tree)
print('The test accuracy is', test_accuracy)

#Confusion MATRIX
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred_tree), annot=True, fmt='d', cmap='Blues', xticklabels=label_enc.classes_, yticklabels=label_enc.classes_)
plt.title('Decision Tree')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# The test accuracy is 0.9290780141843972
