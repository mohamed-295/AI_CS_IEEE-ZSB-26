# %%
# Import libraries
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# %reload_ext autoreload

import pandas as pd
import numpy as np

from utils import randomize, draw_learning_curves
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC

# %%
# Import data from csv file
data = pd.read_csv('data.csv')

# %%
# Fix random seed
np.random.seed(55)

# Prepare features and label data
X = np.array(data[['x1', 'x2']])
y = np.array(data['y'])

# %% [markdown]
# ### Uncomment the code for each one, and examine the learning curve that gets drawn.

# %%
# TODO: Uncomment one of the three classifiers, and hit "Test Run"
# to see the learning curve. Use these to answer the quiz below.

# ## Logistic Regression
# estimator = LogisticRegression() #Right

# ## Decision Tree
# estimator = GradientBoostingClassifier()  #Under

# ## Support Vector Machine
# estimator = SVC(kernel='rbf', gamma=1000) # Over

# %%
draw_learning_curves(X, y, estimator, 10)

# %% [markdown]
# Quiz Question
#
# From the models above, which model underfits, which one overfits, and which one is just right?
#
# Logistic Regression
#
# Decision Tree
#
# Support Vector Machine

# %% [markdown]
# Enter Answers Here:

# %% [markdown]
# Logistic Regression ==> `is just right`

# %% [markdown]
# Decision Tree ==> ` underfits`

# %% [markdown]
# Support Vector Machine ==> `overfits`
